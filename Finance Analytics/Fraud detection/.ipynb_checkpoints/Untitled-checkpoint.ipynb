# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_obj=pd.read_csv("trans_fraud_data.csv")

# %%
df_obj.shape
# Out:
# (6362620, 11)

# %%
df_obj.describe()
# Out:
#          Unnamed: 0          step  trans_amount  sender_old_bal  \
# count  6.362620e+06  6.362620e+06  6.362620e+06    6.362620e+06
# mean   3.181310e+06  2.433972e+02  1.798619e+05    8.338831e+05
# std    1.836730e+06  1.423320e+02  6.038582e+05    2.888243e+06
# min    0.000000e+00  1.000000e+00  0.000000e+00    0.000000e+00
# 25%    1.590655e+06  1.560000e+02  1.338957e+04    0.000000e+00
# 50%    3.181310e+06  2.390000e+02  7.487194e+04    1.420800e+04
# 75%    4.771964e+06  3.350000e+02  2.087215e+05    1.073152e+05
# max    6.362619e+06  7.430000e+02  9.244552e+07    5.958504e+07
#
#        sender_new_bal  receiver_old_bal  receiver_new_bal   check_fraud
# count    6.362620e+06      6.362620e+06      6.362620e+06  6.362620e+06
# mean     8.551137e+05      1.100702e+06      1.224996e+06  1.290820e-03
# std      2.924049e+06      3.399180e+06      3.674129e+06  3.590480e-02
# min      0.000000e+00      0.000000e+00      0.000000e+00  0.000000e+00
# 25%      0.000000e+00      0.000000e+00      0.000000e+00  0.000000e+00
# 50%      0.000000e+00      1.327057e+05      2.146614e+05  0.000000e+00
# 75%      1.442584e+05      9.430367e+05      1.111909e+06  0.000000e+00
# max      4.958504e+07      3.560159e+08      3.561793e+08  1.000000e+00

# %%
df_obj.head()
# Out:
#    Unnamed: 0  step trans_type  trans_amount  sender_name  sender_old_bal  \
# 0           0     1    PAYMENT       9839.64  C1231006815        170136.0
# 1           1     1    PAYMENT       1864.28  C1666544295         21249.0
# 2           2     1   TRANSFER        181.00  C1305486145           181.0
# 3           3     1   CASH_OUT        181.00   C840083671           181.0
# 4           4     1    PAYMENT      11668.14  C2048537720         41554.0
#
#    sender_new_bal     receiver  receiver_old_bal  receiver_new_bal  \
# 0       160296.36  M1979787155               0.0               0.0
# 1        19384.72  M2044282225               0.0               0.0
# 2            0.00   C553264065               0.0               0.0
# 3            0.00    C38997010           21182.0               0.0
# 4        29885.86  M1230701703               0.0               0.0
#
#    check_fraud
# 0            0
# 1            0
# 2            1
# 3            1
# 4            0

# %%
def return_explode_list(explode_count):
    explode_List=[]
    for i in range(0,explode_count):
        if i%2==0:
            explode_List.append(.1)
        else:
            explode_List.append(0)
    return explode_List

# %%
def plot_categorical_value_distribution(data,column_name,disp_column_name):
    total_unique_value=data[column_name].value_counts().shape[0]
    available_color_list_values=list(sns.crayons.values())
    colors_list = random.choices(available_color_list_values,k=total_unique_value)
    figure = plt.figure(figsize = [13.66, 7.3])
    plt.subplot(1, 2, 1)
    
    ax=sns.barplot(data[column_name].value_counts().index, data[column_name].value_counts(), palette  = colors_list)
#     plt.yticks(range(0, 2300000, 100000))
    plt.xlabel(disp_column_name, size = 14)
    plt.ylabel('Frequency', size = 14)
    plt.title('Frequency occurence of each '+ disp_column_name, y=1.05, size = 16)
    for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()+.5))

    explode_list=return_explode_list(total_unique_value)
    plt.subplot(1, 2, 2)
    data[column_name].value_counts().plot(kind='pie', figsize=[13.66, 7.3], autopct='%1.1f%%', 
                                           startangle=90, shadow=True, labels=None, pctdistance=1.12, colors=colors_list, explode=explode_list)
    plt.title('Proportion of each type occurence in '+ disp_column_name, y=1.05, size = 16)
    plt.ylabel('')
    plt.axis('equal')
    plt.legend(labels = data[column_name].value_counts().index, loc = 'upper left', frameon=False)
    plt.tight_layout(pad=2.0)
    plt.show()

# %%
available_color_list_values=list(sns.crayons.values())

# %% [markdown]
# **Question:** Find the **frequency** and **proportions** of various **categorcal values** in Data?

# %%
plot_categorical_value_distribution(df_obj,"trans_type","Transaction Type")

# %% [markdown]
# **<h4>Question 2:** What is the **average amount** that has been **transfered** using **each transaction type**?</h4>

# %%
df_avg_amt_transtype=pd.DataFrame(df_obj.groupby("trans_type").mean()["trans_amount"].reset_index())
df_avg_amt_transtype.set_index("trans_type",inplace=True)

# %%
df_avg_amt_transtype["trans_amount"]=round(df_avg_amt_transtype["trans_amount"],2)

# %%
df_avg_amt_transtype["trans_amount"].sum()
# Out:
# 1274382.48

# %%
    figure = plt.figure(figsize = [13.66, 7.3])
    plt.subplot(1, 2, 1)
    colors_list = random.choices(available_color_list_values,k=5)

    ax=sns.barplot(df_avg_amt_transtype.index, df_avg_amt_transtype["trans_amount"].sort_values(), palette=colors_list )
    plt.xlabel("Transaction Type", size = 14)
    plt.ylabel('Average Amount', size = 14)
    plt.title('Average amount transacted for each Transaction Type', y=1.05, size = 16)
    for p in ax.patches:
        ax.annotate('{:.2f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()+.8))

    explode_list=[.1,0,0,0,.1]
    plt.subplot(1, 2, 2)
    df_avg_amt_transtype["trans_amount"].plot(kind='pie', figsize=[13.66, 7.3], autopct='%1.1f%%', 
                                           startangle=90, shadow=True, labels=None, pctdistance=1.12, colors=colors_list, explode=explode_list)
    plt.title('Transaction Amount share by Transaction Type', y=1.05, size = 16)
    plt.ylabel('')
    plt.axis('equal')
    plt.legend(labels = df_avg_amt_transtype.index, loc = 'upper left', frameon=False)
    plt.tight_layout(pad=2.0)
    plt.show()

# %% [markdown]
# **<h4>Question 3:** What is the **proportion of customers who are fraud and who are not**?</h4>

# %%
plot_categorical_value_distribution(df_obj,"check_fraud","Check Fraud")

# %% [markdown]
# **<h4>* Question 4:** What is the **frequency distribution of transactions types** happened **with respect to customer being fraud**?</h4>

# %%
plt.figure(figsize = [12, 8])
ax = sns.countplot(x = 'trans_type', hue = 'check_fraud', data = df_obj, palette = random.choices(available_color_list_values,k=2))
total = df_obj.shape[0]
for p in ax.patches:
  percentage = '{:.2f}%'.format(100 * p.get_height()/total)
  x = p.get_x() + p.get_width() / 6
  y = p.get_y() + p.get_height()
  ax.annotate(percentage, (x, y))
ax.set_yticks(range(0, 2300000, int(1e5)))
ax.set_xlabel("Transaction Type", size = 14)
ax.set_ylabel("Frequency of transactions", size = 14)
ax.set_title("Fraudulent vs Non-Fraudulent Transaction per Transaction Type", size = 16)
ax.legend(labels = ['Not Fraud', 'Fraud'])
plt.show()

# %% [markdown]
# **<h4>Question 5:** What is the **minimumn & maximum transaction amount identified as fraudulent** transaction?</h4>

# %%
min_amount=df_obj[df_obj["check_fraud"]==1]["trans_amount"].min()
max_amount=df_obj[df_obj["check_fraud"]==1]["trans_amount"].max()
print('Minimum amount transacted as fraudulent =', min_amount)
print('Maximum amount transacted as fraudulent =', max_amount)
# Out:
# Minimum amount transacted as fraudulent = 0.0
# Maximum amount transacted as fraudulent = 10000000.0

# %% [markdown]
# **<h4>Question 6:** What is the **minimumn & maximum transaction amount identified as non-fraudulent** transaction?</h4>

# %%
min_amount=df_obj[df_obj["check_fraud"]==0]["trans_amount"].min()
max_amount=df_obj[df_obj["check_fraud"]==0]["trans_amount"].max()
print('Minimum amount transacted as fraudulent =', min_amount)
print('Maximum amount transacted as fraudulent =', max_amount)
# Out:
# Minimum amount transacted as fraudulent = 0.01
# Maximum amount transacted as fraudulent = 92445516.64

# %%
df_obj.drop(["sender_name","receiver"],inplace=True,axis=1) #"Unnamed: 0"

# %%
sns.heatmap(df_obj.corr(),annot=True,cmap="YlOrRd")

# %%
# receiver_old_bal and receiver_new_bal are highly correalted. So any one of them can be dropped p=.98
# sender_old_bal and sender_new_bal are highly correlated. So any of them can be dropped
df_obj.drop(["receiver_new_bal","sender_new_bal"],axis=1,inplace=True)

# %%
df_trasfer_cashout_data=df_obj[(df_obj["trans_type"]=="TRANSFER") | (df_obj["trans_type"]=="CASH_OUT")]

# %%
df_trasfer_cashout_data.head()
# Out:
#     Unnamed: 0  step trans_type  trans_amount  sender_old_bal  \
# 2            2     1   TRANSFER        181.00           181.0
# 3            3     1   CASH_OUT        181.00           181.0
# 15          15     1   CASH_OUT     229133.94         15325.0
# 19          19     1   TRANSFER     215310.30           705.0
# 24          24     1   TRANSFER     311685.89         10835.0
#
#     receiver_old_bal  check_fraud
# 2                0.0            1
# 3            21182.0            1
# 15            5083.0            0
# 19           22425.0            0
# 24            6267.0            0

# %%
sns.pairplot(data=df_trasfer_cashout_data,hue="check_fraud")
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-4ece69250d01> in <module>
# ----> 1 sns.pairplot(data=df_trasfer_cashout_data,hue="check_fraud")
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119     if kind == "scatter":
#    2120         from .relational import scatterplot  # Avoid circular import
# -> 2121         plotter(scatterplot, **plot_kws)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py in map_offdiag(self, func, **kwargs)
#    1510         """
#    1511
# -> 1512         self.map_lower(func, **kwargs)
#    1513         self.map_upper(func, **kwargs)
#    1514         return self
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py in map_lower(self, func, **kwargs)
#    1440                 color = self.palette[k] if kw_color is None else kw_color
#    1441                 func(data_k[x_var], data_k[y_var], label=label_k,
# -> 1442                      color=color, **kwargs)
#    1443
#    1444             self._clean_axis(ax)
#
# C:\Anaconda\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1339         ax = plt.gca()
#    1340
# -> 1341     p.plot(ax, kwargs)
#    1342
#    1343     return ax
#
# C:\Anaconda\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     914
#     915         args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# --> 916         points = ax.scatter(*args, **kws)
#     917
#     918         # Update the paths to get different marker shapes. This has to be
#
# C:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4517                 self.set_ymargin(0.05)
#    4518
# -> 4519         self.add_collection(collection)
#    4520         self.autoscale_view()
#    4521
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in add_collection(self, collection, autolim)
#    1869
#    1870         if autolim:
# -> 1871             self.update_datalim(collection.get_datalim(self.transData))
#    1872
#    1873         self.stale = True
#
# C:\Anaconda\lib\site-packages\matplotlib\collections.py in get_datalim(self, transData)
#     199             result = mpath.get_path_collection_extents(
#     200                 transform.frozen(), paths, self.get_transforms(),
# --> 201                 offsets, transOffset.frozen())
#     202             result = result.inverse_transformed(transData)
#     203         else:
#
# C:\Anaconda\lib\site-packages\matplotlib\path.py in get_path_collection_extents(master_transform, paths, transforms, offsets, offset_transform)
#     962     return Bbox.from_extents(*_path.get_path_collection_extents(
#     963         master_transform, paths, np.atleast_3d(transforms),
# --> 964         offsets, offset_transform))
#     965
#     966
#
# C:\Anaconda\lib\site-packages\matplotlib\path.py in vertices(self)
#     195         )
#     196
# --> 197     @property
#     198     def vertices(self):
#     199         """
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000002123010DAE8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\Anaconda\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# C:\Anaconda\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# C:\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Anaconda\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# C:\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# C:\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2603                 artists.remove(spine)
#    2604
# -> 2605         self._update_title_position(renderer)
#    2606
#    2607         if not self.axison or inframe:
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2545                     if (ax.xaxis.get_label_position() == 'top' or
#    2546                             ax.xaxis.get_ticks_position() in choices):
# -> 2547                         bb = ax.xaxis.get_tightbbox(renderer)
#    2548                     else:
#    2549                         bb = ax.get_window_extent(renderer)
#
# C:\Anaconda\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1161             return
#    1162
# -> 1163         ticks_to_draw = self._update_ticks()
#    1164
#    1165         self._update_label_position(renderer)
#
# C:\Anaconda\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1081         major_labels = self.major.formatter.format_ticks(major_locs)
#    1082         major_ticks = self.get_major_ticks(len(major_locs))
# -> 1083         self.major.formatter.set_locs(major_locs)
#    1084         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1085             tick.update_position(loc)
#
# C:\Anaconda\lib\site-packages\matplotlib\ticker.py in set_locs(self, locs)
#     684                 self._compute_offset()
#     685             self._set_order_of_magnitude()
# --> 686             self._set_format()
#     687
#     688     def _compute_offset(self):
#
# C:\Anaconda\lib\site-packages\matplotlib\ticker.py in _set_format(self)
#     770             _locs = self.locs
#     771         locs = (np.asarray(_locs) - self.offset) / 10. ** self.orderOfMagnitude
# --> 772         loc_range = np.ptp(locs)
#     773         # Curvilinear coordinates can yield two identical points.
#     774         if loc_range == 0:
#
# <__array_function__ internals> in ptp(*args, **kwargs)
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in ptp(a, axis, out, keepdims)
#    2541         else:
#    2542             return ptp(axis=axis, out=out, **kwargs)
# -> 2543     return _methods._ptp(a, axis=axis, out=out, **kwargs)
#    2544
#    2545
#
# C:\Anaconda\lib\site-packages\numpy\core\_methods.py in _ptp(a, axis, out, keepdims)
#     228 def _ptp(a, axis=None, out=None, keepdims=False):
#     229     return um.subtract(
# --> 230         umr_maximum(a, axis, None, out, keepdims),
#     231         umr_minimum(a, axis, None, None, keepdims),
#     232         out
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
log_class=LogisticRegression()
neigh_class=KNeighborsClassifier(n_neighbors=40)
svr_class=SVR()
dec_tree_class=DecisionTreeClassifier()
random_frst_class=RandomForestClassifier(n_estimators=100)
xg_boost_class=XGBClassifier()

# %%
from sklearn.preprocessing import StandardScaler
std_sclr=StandardScaler()

# %%
df_trasfer_cashout_data=pd.get_dummies(df_trasfer_cashout_data,columns=["trans_type"],drop_first=True)

# %%
y=df_trasfer_cashout_data["check_fraud"]
X=df_trasfer_cashout_data.drop("check_fraud",axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,)

# %%
print(cross_val_score(log_class,X=X,y=y,scoring="f1_weighted",cv=100).mean())

# %%
sklearn.metrics.SCORERS.keys()
