# %%
import pandas as pd
import numpy as np

# %%
df_gender_age_train= pd.read_csv("gender_age_train.csv",dtype={"device_id":str})

# %%
df_gender_age_train.head()
# Out:
#               device_id gender  age   group
# 0  -8076087639492060000      M   35  M32-38
# 1  -2897161552818060000      M   35  M32-38
# 2  -8260683887967670000      M   35  M32-38
# 3  -4938849341048080000      M   30  M29-31
# 4    245133531816851000      M   30  M29-31

# %%
#no duplicates found in gender_age_table
df_gender_age_train[df_gender_age_train.duplicated(subset=['device_id'])]
# Out:
# Empty DataFrame
# Columns: [device_id, gender, age, group]
# Index: []

# %%
df_events_data_from_insaid=pd.read_csv("Modified_Event_Data_final - Copy.csv", dtype={"device_id":str})

# %%
df_events_data_from_insaid.iloc[0,2]
# Out:
# 2.9182687948017176e+16

# %%
df_events_data_from_insaid.head()
# Out:
#    Unnamed: 0  event_id          device_id      timestamp  longitude  \
# 0           0         1  29182687948017100  5/1/2016 0:55  77.266049
# 1           1      7104  29182687948017100  5/2/2016 9:37  77.266049
# 2           2     29661  29182687948017100  5/4/2016 0:56  77.266049
# 3           3     33133  29182687948017100  5/6/2016 5:01  77.266049
# 4           4     38980  29182687948017100  5/6/2016 9:55  77.266049
#
#    latitude   city  state newState newCity
# 0  28.68161  Delhi  Delhi    Delhi   Delhi
# 1  28.68161  Delhi  Delhi    Delhi   Delhi
# 2  28.68161  Delhi  Delhi    Delhi   Delhi
# 3  28.68161  Delhi  Delhi    Delhi   Delhi
# 4  28.68161  Delhi  Delhi    Delhi   Delhi

# %%
df_events_data_from_insaid.tail()
# Out:
#          Unnamed: 0  event_id            device_id       timestamp  longitude  \
# 1048570     1048570    946443  2137076037204830000   5/7/2016 5:11  73.929032
# 1048571     1048571    972312  2137076037204830000  5/7/2016 21:31  73.929032
# 1048572     1048572    975753  2137076037204830000  5/7/2016 23:12  73.929032
# 1048573     1048573    977281  2137076037204830000   5/7/2016 1:37  73.929032
# 1048574     1048574    977316  2137076037204830000   5/7/2016 1:10  73.929032
#
#           latitude  city        state     newState newCity
# 1048570  18.583998  Pune  Maharashtra  Maharashtra    Pune
# 1048571  18.583998  Pune  Maharashtra  Maharashtra    Pune
# 1048572  18.583998  Pune  Maharashtra  Maharashtra    Pune
# 1048573  18.583998  Pune  Maharashtra  Maharashtra    Pune
# 1048574  18.583998  Pune  Maharashtra  Maharashtra    Pune

# %%
# Find device id from user table has entries in event data
list_dev_id={}
def get_event_entry_from_device_id_in_user(row):
    device_id=row.device_id
    print(device_id,len(df_events_data_from_insaid[df_events_data_from_insaid.device_id==str(device_id)]))
    list_dev_id[device_id]=len(df_events_data_from_insaid[df_events_data_from_insaid.device_id==str(device_id)])

# %%
# df_gender_age_train.apply(get_event_entry_from_device_id_in_user,axis=1)

# %%
df_gender_age_train[df_gender_age_train.device_id==29182687948017100]
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [device_id, gender, age, group]
# Index: []

# %%
df_events_data_from_insaid[df_events_data_from_insaid.device_id=="29182687948017100"]
# Out:
#      Unnamed: 0  event_id          device_id       timestamp  longitude  \
# 0             0         1  29182687948017100   5/1/2016 0:55  77.266049
# 1             1      7104  29182687948017100   5/2/2016 9:37  77.266049
# 2             2     29661  29182687948017100   5/4/2016 0:56  77.266049
# 3             3     33133  29182687948017100   5/6/2016 5:01  77.266049
# 4             4     38980  29182687948017100   5/6/2016 9:55  77.266049
# 5             5     66398  29182687948017100   5/1/2016 1:56  77.266049
# 6             6     70894  29182687948017100   5/6/2016 1:14  77.266049
# 7             7     87185  29182687948017100   5/1/2016 9:20  77.266049
# 8             8     94644  29182687948017100   5/7/2016 7:16  77.266049
# 9             9    110018  29182687948017100  5/6/2016 21:00  77.266049
# 10           10    120190  29182687948017100   5/2/2016 0:20  77.266049
# 11           11    120191  29182687948017100   5/2/2016 0:21  77.266049
# ...

# %%
df_events_data_from_insaid.head()
# Out:
#    Unnamed: 0  event_id          device_id      timestamp  longitude  \
# 0           0         1  29182687948017100  5/1/2016 0:55  77.266049
# 1           1      7104  29182687948017100  5/2/2016 9:37  77.266049
# 2           2     29661  29182687948017100  5/4/2016 0:56  77.266049
# 3           3     33133  29182687948017100  5/6/2016 5:01  77.266049
# 4           4     38980  29182687948017100  5/6/2016 9:55  77.266049
#
#    latitude   city  state newState newCity
# 0  28.68161  Delhi  Delhi    Delhi   Delhi
# 1  28.68161  Delhi  Delhi    Delhi   Delhi
# 2  28.68161  Delhi  Delhi    Delhi   Delhi
# 3  28.68161  Delhi  Delhi    Delhi   Delhi
# 4  28.68161  Delhi  Delhi    Delhi   Delhi

# %%
df_merged=df_gender_age_train.merge(df_events_data_from_insaid,how="inner",on="device_id",indicator=True)

# %%
df_merged._merge.unique()
# Out:
# [both]
# Categories (1, object): [both]

# %%
df_merged[df_merged._merge=="both"].shape
# Out:
# (1001454, 14)

# %%
df_merged[df_merged.duplicated(subset=["device_id"])].shape
# Out:
# (992322, 13)

# %%
df_gender_age_train.shape
# Out:
# (74645, 4)

# %%
df_join=df_gender_age_train.join(df_events_data_from_insaid,how="inner",on="device_id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-feb0989b772a> in <module>
# ----> 1 df_join=df_gender_age_train.join(df_events_data_from_insaid,how="inner",on="device_id")
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# ...
